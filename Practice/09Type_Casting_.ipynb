# %% [markdown]
# #09. Type Casting
# ##Introduction
#
# Type conversion means changing a value from one data type to another.
#
# Python provides functions such as int(), float(), str() and bool() for explicit conversion.

# %% [markdown]
# ##String to Integer

# %%
number = "45"

converted_number = int(number)

print(converted_number)
print(type(converted_number))
# Out:
# 45
# <class 'int'>

# %% [markdown]
# ##Integer to Float

# %%
number = 25

result = float(number)

print(result)
print(type(result))
# Out:
# 25.0
# <class 'float'>

# %% [markdown]
# ##Integer to String

# %%
age = 23

age_text = str(age)

print(age_text)
print(type(age_text))
# Out:
# 23
# <class 'str'>

# %% [markdown]
# ##Float to Integer

# %%
price = 99.85

price_int = int(price)

print(price_int)
#The decimal part is removed.
# Out:
# 99

# %% [markdown]
# ##Boolean Conversion

# %%
print(bool(1))
print(bool(0))
# Out:
# True
# False

# %% [markdown]
# Convert string to integer.

# %%
x = "60"
print(int(x))
# Out:
# 60

# %% [markdown]
# Convert string to float.

# %%
x = "45.5"
print(float(x))
# Out:
# 45.5

# %% [markdown]
# Convert integer to string.

# %%
x = 75
print(str(x))
# Out:
# 75

# %% [markdown]
# Convert integer to float.

# %%
x = 40
print(float(x))
# Out:
# 40.0

# %% [markdown]
# Convert float to integer.

# %%
x = 88.9
print(int(x))
# Out:
# 88

# %% [markdown]
# Add two string numbers after conversion.

# %%
a = "30"
b = "20"

print(int(a) + int(b))
# Out:
# 50

# %% [markdown]
# Multiply a converted value.

# %%
number = "7"

print(int(number) * 6)
# Out:
# 42

# %% [markdown]
# Convert input to integer.

# %%
age = int(input("Enter your age: "))
print(age)
# Out:
# Enter your age: 60
# 60

# %% [markdown]
# Check automatic numeric conversion.

# %%
a = 8
b = 2.5

result = a + b

print(result)
print(type(result))
# Out:
# 10.5
# <class 'float'>

# %% [markdown]
# ##Overall Observation
#
# I learned that type conversion is important when working with different types of values. It is especially useful when taking numeric input from users.
